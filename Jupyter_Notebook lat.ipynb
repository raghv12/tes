# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sraghav Sharma**
#
# Student

# %% [markdown]
# *I am interested in data science because it amazes me how data driven decisions turn out to be so accurate and game changing*

# %% [markdown]
# #### It is compiling code written in python language

# %%
1+31
# Out:
# 32

# %% [markdown]
# ~~wow~~
#
#
# [I'm an inline-style link](https://www.youtube.com)
#
#
# Hey, I am **Raghav**
